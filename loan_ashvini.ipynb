# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

# %%
print(os.getcwd())
loan = pd.read_csv("loan.csv")
loan.head(5)
# Out:
# C:\Users\inascha7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# ...

# %%
loan.shape
# Out:
# (39717, 111)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
# Dropping columns having all missing values more than 50%

loan_mod = loan.dropna(thresh=loan.shape[0]*0.5,how='all',axis=1)

# %%
loan_mod.shape
# Out:
# (39717, 54)

# %%
# Dropping columns having all un important  values
loan_mod = loan_mod.drop(['desc', 'member_id', 'id', 'url','delinq_amnt'], axis=1)

## Deleting column having all values as same. So not adding any importance in analysis
loan_mod = loan_mod.drop(['delinq_amnt', 'acc_now_delinq', 'application_type',
                                                         'policy_code', 'pymnt_plan', 'initial_list_status', 'chargeoff_within_12_mths',
                                                          'tax_liens', 'collections_12_mths_ex_med'], axis=1)
## Deleting string columns having most of as unique values
loan_mod = loan_mod.drop(['emp_title'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-9be9ce82b381> in <module>
#       7 #                                                           'tax_liens', 'collections_12_mths_ex_med'], axis=1)
#       8 ## Deleting string columns having most of as unique values
# ----> 9 loan_mod = loan_mod.drop(['emp_title'], axis=1)
#      10
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
loan_mod.shape
# Out:
# (39717, 40)

# %%
# null_columns_dropped_data[null_columns_dropped_data.isnull().sum(axis=1) >= 2]
loan_mod['term_months'] = loan_mod['term'].str.rstrip('months')
del loan_mod['term']

# %%
loan_mod['int_rate_percentage'] = loan_mod['int_rate'].str.rstrip('%')
del loan_mod['int_rate']

# %%
loan_mod['emp_length_years'] = loan_mod['emp_length'].str.rstrip('years ')
loan_mod['emp_length_years'].replace({'10+': '10'}, inplace=True)
loan_mod['emp_length_years'][loan_mod['emp_length_years'] == '< 1'] = '0.5'
del loan_mod['emp_length']

# %%
loan_mod['revol_util_percentage'] = loan_mod['revol_util'].str.rstrip('%')
del loan_mod['revol_util']

# %%
loan_mod['issue_d_month'], loan_mod['issue_d_year'] = loan_mod[
    'issue_d'].str.split('-').str

loan_mod['last_credit_pull_d_month'], loan_mod['last_credit_pull_d_year'] = loan_mod[
    'last_credit_pull_d'].str.split('-').str

loan_mod['last_pymnt_d_month'], loan_mod['last_pymnt_d_year'] = loan_mod[
    'last_pymnt_d'].str.split('-').str

loan_mod['earliest_cr_line_month'], loan_mod['earliest_cr_line_year'] = loan_mod[
    'earliest_cr_line'].str.split('-').str

# %%
loan_mod['issue_d_year'] = '20' + loan_mod['issue_d_year']

# %%
# delte the rows with loan status = Current
loan_mod = loan_mod[loan_mod.loan_status !='Current']

# %%
## Final dataset for Exploratory Data Analytics

df = loan_mod

# %%
#Univariate Analysis

df["loan_status"].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %%
plt.ylabel('Loan Amount')
sns.boxplot( y=df["loan_amnt"] )
plt.show()

# %%
sns.countplot(x= df["loan_status"])
plt.show()

# %%
sns.countplot(x='grade', data=df)
plt.show()

# %%
sns.countplot(x='emp_length_years', data=df)
plt.xlabel('Employee Working Experience')
plt.show()

# %%
sns.countplot(x='emp_length_years', hue='loan_status', data=df)
plt.xlabel('Employee Working Experience')
plt.show()

# %%
sns.distplot(df['funded_amnt'])
plt.show()

# %%
df['grade'] = df['grade'].astype('category')
df['int_rate_percentage'] = df['int_rate_percentage'].astype('float')


sns.boxplot(y='int_rate_percentage', x='grade', data=df)
plt.ylabel('Interest Rate Percentage')
plt.show()

# %%
sns.boxplot(y='int_rate_percentage', x='loan_status', data=df)
plt.ylabel('Interest Rate Percentage')
plt.xlabel('Loan Status')
plt.show()

# %%
#Segmented Univariate Analysis

sns.countplot(x='purpose', hue="loan_status", data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot( y="loan_amnt", x='loan_status' , data=df)
plt.ylabel('Loan Amount')
plt.show()

# %%
sns.countplot( x="term_months", hue='loan_status', data=df)
plt.xlabel('Loan Term in Months')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot( x="term_months", hue='purpose', data=df)
plt.xlabel('Loan Term in Months')
plt.show()

# %%
sns.countplot(x='purpose', hue='loan_status', data=df)
plt.title('No of loans granted for various purpose')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='home_ownership',hue='loan_status', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))

sns.countplot(x='addr_state',hue='loan_status', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#Bivariate Plots

plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
plt.show()

# %%
g = df[df['loan_status']=='Charged Off'].groupby('addr_state')['loan_status'].count().reset_index()
plt.figure(figsize=(10,10))
sns.barplot(y='addr_state', x='loan_status', data=g)
plt.xlabel('Count of loan status to be defaulter')
plt.ylabel('State')
plt.show()

# %%
df_agg = df[df['funded_amnt'] <= 7000].groupby(['loan_status'])['funded_amnt'].count().reset_index()
sns.barplot(x='loan_status', y='funded_amnt', data=df_agg)
plt.title('Loan Amount granted less than 7 lakhs')
plt.xlabel('Loan Status')
plt.ylabel('Loan Amount Granted')
plt.show()

# %%
df_agg = df[df['funded_amnt'] > 7000].groupby(['loan_status'])['funded_amnt'].count().reset_index()
sns.barplot(x='loan_status', y='funded_amnt', data=df_agg)
plt.title('Loan Amount granted more than 7 lakhs')
plt.xlabel('Loan Status')
plt.ylabel('Loan Amount Granted')
plt.show()
